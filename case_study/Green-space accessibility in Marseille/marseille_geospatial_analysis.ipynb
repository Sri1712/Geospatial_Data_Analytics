# %% [markdown]
# ## Green-space accessibility in Marseille

# %%
# Imports and file locations
from pathlib import Path

import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Change DATA_DIR only if the supplied files are moved.
DATA_DIR = Path(r"C:\Users\Srilathaa Vasu\Downloads")
PARKS_FILE = DATA_DIR / "marseille_parcs_jardins_2018.csv"
QUARTIERS_FILE = DATA_DIR / "quartiers-marseille.geojson"
RESULTS_DIR = Path.cwd() / "marseille_analysis_results"
RESULTS_DIR.mkdir(exist_ok=True)
